# %%
from IPython.display import HTML
from pathlib import Path

css_rules = Path('custom.css').read_text()
HTML('<style>' + css_rules + '</style>')
# Out:
# <style>/* Settings for dataframes */
#
# /* title of columns */
# table.dataframe thead th {
#     font-size: 1.2em !important;
#     padding-top: 0.2em !important;
#     padding-bottom: 0.2em !important;
# }
#
# /* title of rows */
# table.dataframe tbody th {
#     font-size: 1.2em !important;
#     background: rgba(199, 199, 199, 0.356) !important;
#     border: 1px solid black !important;
# }
#
# /* style for each cell */
# table.dataframe td {
#     font-size: 1.15em !important;
#     border: 1px solid black !important;
# }
#
# /* disable zebra-style */
# table.dataframe tbody tr {
#     background: white !important;
# }
#
# /* row color on hover */
# table.dataframe tbody tr:hover {
#     background: rgba(43, 137, 226, 0.144) !important;
# }
#
# /* Settings for "ordinary" tables */
#
# /* alignment */
# table {
#     margin-left: initial !important;
# }
#
# /* title of columns */
# table thead th {
#     font-size: 1.2em !important;
#     padding-top: 0.2em !important;
# ...

# %% [markdown]
# # Miniproyecto
#
# Realizar un **EDA** en profundidad sobre cualquier dataset utilizando [esta competición de Kaggle](https://www.kaggle.com/c/python-cientfico/overview).
#
# ## Cheatsheets
#
# Se facilitan una serie de Cheatsheets elaboradas por [DataCamp](https://www.datacamp.com/) que les pueden servir como ayuda para este miniproyecto y futuros trabajos.
#
# $\Rightarrow$ [Cheatsheets de Python científico](resources/mini_project/python-cheatsheets.pdf)
#
# ## Entrega del proyecto
#
# La entrega del proyecto deberá hacerse antes del **31 de mayo de 2019 a las 23:00h** utilizando [este enlace de subida de Dropbox](https://www.dropbox.com/request/LzEoSOPEShPQRRsPw8ZE).
#
# Se permiten entregas **FUERA DE PLAZO** hasta el **7 de junio de 2019 a las 23:00h**. Los proyectos entregados fuera de plazo tendrán una **penalización de 1.5 puntos**.
#
# ## Contacto
#
# Para cualquier duda, comentario o sugerencia pueden contactar con nosotros utilizando los siguientes medios:
#
# Profesor | Email | Telegram
# - | - | -
# Sergio Delgado Quintero | sdelquin@gmail.com | [@sdelquin](https://t.me/sdelquin)
# Alejandro Moreno Alberto | alex.23p10@gmail.com |
#
# ## Rúbrica
#
# Los proyectos se valorarán de **0 a 10** teniendo en cuenta los porcentajes asociados a cada **criterio** según se indica en la siguiente rúbrica:
#
# Criterio | Valoración
# - | -
# ¿Se ha realizado la carga de datos? | $5\%$
# ¿Se han mostrado datos utilizando `head`/`info`/`describe`? | $5\%$
# ¿Se ha realizado gestión de valores nulos? | $5\%$
# ¿Se han utilizado histogramas para visualización? | $10\%$
# ¿Se han utilizado diagramas de dispersión para visualización? | $10\%$
# ¿Se ha llevado a cabo transformación de columnas? | $10\%$
# ¿Se ha llevado a cabo selección/filtrado de columnas? | $5\%$
# ¿Se ha aplicado un algoritmo predictivo? | $20\%$
# ¿Se han seleccionado hiperparámetros para el algoritmo utilizado? | $10\%$
# ¿Es adecuado el algoritmo utilizado? | $10\%$
# ¿Se han implementado extras? | $10\%$
#
# ### Penalización por copia
#
# En caso de detectar una cantidad anómala de **líneas de código similares** se aplicará una penalización a ambas personas de **1.5 puntos**.
